# %%
from tensorflow import keras
from keras.preprocessing import image
import numpy as np
import pandas as pd


import matplotlib.pyplot as plt
from PIL import Image

# %%
model = keras.models.load_model(r'E:\kaggle\working\final_model.h5')
label =  {0:"benign",1:"malignant"}

# %%
img_ = image.load_img(r"Downloads\download.jpg", target_size=(224, 224))
imag = image.img_to_array(img_)
imag = np.expand_dims(imag, axis=0)
pred = model.predict(imag)
pred = np.argmax(pred,axis=1)
print(pred)
print(label[pred[0]])
plt.imshow(img_)
# Out:
# [1]
# malignant

# %%
img_ = image.load_img(r"E:\project\BreaKHis 400X\test\benign\SOB_B_TA-14-19854C-400-008.png", target_size=(224, 224))
imag = image.img_to_array(img_)
imag = np.expand_dims(imag, axis=0)
pred = model.predict(imag)
pred = np.argmax(pred,axis=1)
print(pred)
print(label[pred[0]])
plt.imshow(img_)
# Out:
# [0]
# benign

# %%
img_ = image.load_img(r"Downloads\histopathology image.jpg", target_size=(224, 224))
imag = image.img_to_array(img_)
imag = np.expand_dims(imag, axis=0)
pred = model.predict(imag)
pred = np.argmax(pred,axis=1)
print(pred)
print(label[pred[0]])
plt.imshow(img_)
# Out:
# [1]
# malignant

# %%
img_ = image.load_img(r"Downloads\images.jpg", target_size=(224, 224))
imag = image.img_to_array(img_)
imag = np.expand_dims(imag, axis=0)
pred = model.predict(imag)
pred = np.argmax(pred,axis=1)
print(pred)
print(label[pred[0]])
plt.imshow(img_)
# Out:
# [1]
# malignant

# %%
img_ = image.load_img(r"Downloads\images (1).jpg", target_size=(224, 224))
imag = image.img_to_array(img_)
imag = np.expand_dims(imag, axis=0)
pred = model.predict(imag)
pred = np.argmax(pred,axis=1)
print(pred)
print(label[pred[0]])
plt.imshow(img_)
# Out:
# [1]
# malignant
